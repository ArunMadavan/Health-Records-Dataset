# %%
import pandas as pd

# %%
# loading the data

train_data = pd.read_parquet("train.parquet")
train_data.head()
# Out:
#                             Patient-Uid       Date           Incident
# 0  a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2019-03-09  PRIMARY_DIAGNOSIS
# 1  a0dc93f2-1c7c-11ec-9cd2-16262ee38c7f 2015-05-16  PRIMARY_DIAGNOSIS
# 3  a0dc94c6-1c7c-11ec-a3a0-16262ee38c7f 2018-01-30     SYMPTOM_TYPE_0
# 4  a0dc950b-1c7c-11ec-b6ec-16262ee38c7f 2015-04-22        DRUG_TYPE_0
# 8  a0dc9543-1c7c-11ec-bb63-16262ee38c7f 2016-06-18        DRUG_TYPE_1

# %%
# sorting ascending 

train_data = train_data.sort_values(['Patient-Uid', 'Date'])
train_data.head()
# Out:
#                                   Patient-Uid       Date        Incident
# 1750087  a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2015-09-22     DRUG_TYPE_7
# 1473893  a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-04-13  SYMPTOM_TYPE_2
# 1387922  a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-05-02     DRUG_TYPE_7
# 223191   a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-11-23  SYMPTOM_TYPE_0
# 557302   a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-11-23     DRUG_TYPE_9

# %%
# Create binary labels for training (1 for eligible, 0 for not eligible)

train_data['Target'] = (train_data['Incident'] == 'TARGET DRUG').astype(int)
train_data
# Out:
#                                    Patient-Uid       Date        Incident  \
# 1750087   a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2015-09-22     DRUG_TYPE_7
# 1473893   a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-04-13  SYMPTOM_TYPE_2
# 1387922   a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-05-02     DRUG_TYPE_7
# 223191    a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-11-23  SYMPTOM_TYPE_0
# 557302    a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-11-23     DRUG_TYPE_9
# ...                                        ...        ...             ...
# 26581536  a0f0d582-1c7c-11ec-a6c1-16262ee38c7f 2020-06-19     DRUG_TYPE_6
# 27737944  a0f0d582-1c7c-11ec-a6c1-16262ee38c7f 2020-07-09     TARGET DRUG
# 20027927  a0f0d582-1c7c-11ec-a6c1-16262ee38c7f 2020-07-10     DRUG_TYPE_1
# 14145873  a0f0d582-1c7c-11ec-a6c1-16262ee38c7f 2020-08-05     TARGET DRUG
# 23797706  a0f0d582-1c7c-11ec-a6c1-16262ee38c7f 2020-08-08     DRUG_TYPE_5
#
#           Target
# 1750087        0
# 1473893        0
# 1387922        0
# 223191         0
# 557302         0
# ...          ...
# 26581536       0
# 27737944       1
# 20027927       0
# 14145873       1
# 23797706       0
#
# [3220868 rows x 4 columns]

# %%
# Feature engineering: extract time-based features from the date column

train_data['Month'] = train_data['Date'].dt.month
train_data['Year'] = train_data['Date'].dt.year

train_data.head()
# Out:
#                                   Patient-Uid       Date        Incident  \
# 1750087  a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2015-09-22     DRUG_TYPE_7
# 1473893  a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-04-13  SYMPTOM_TYPE_2
# 1387922  a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-05-02     DRUG_TYPE_7
# 223191   a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-11-23  SYMPTOM_TYPE_0
# 557302   a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-11-23     DRUG_TYPE_9
#
#          Target  Month  Year
# 1750087       0      9  2015
# 1473893       0      4  2018
# 1387922       0      5  2018
# 223191        0     11  2018
# 557302        0     11  2018

# %%
# One-hot encoding categorical features

train_data = pd.get_dummies(train_data, columns=['Incident'])

train_data.head(4)
# Out:
#                                   Patient-Uid       Date  Target  Month  Year  \
# 1750087  a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2015-09-22       0      9  2015
# 1473893  a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-04-13       0      4  2018
# 1387922  a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-05-02       0      5  2018
# 223191   a0db1e73-1c7c-11ec-ae39-16262ee38c7f 2018-11-23       0     11  2018
#
#          Incident_DRUG_TYPE_0  Incident_DRUG_TYPE_1  Incident_DRUG_TYPE_10  \
# 1750087                     0                     0                      0
# 1473893                     0                     0                      0
# 1387922                     0                     0                      0
# 223191                      0                     0                      0
#
#          Incident_DRUG_TYPE_11  Incident_DRUG_TYPE_12  ...  \
# 1750087                      0                      0  ...
# 1473893                      0                      0  ...
# 1387922                      0                      0  ...
# 223191                       0                      0  ...
#
#          Incident_SYMPTOM_TYPE_7  Incident_SYMPTOM_TYPE_8  \
# 1750087                        0                        0
# 1473893                        0                        0
# 1387922                        0                        0
# 223191                         0                        0
#
#          Incident_SYMPTOM_TYPE_9  Incident_TARGET DRUG  Incident_TEST_TYPE_0  \
# 1750087                        0                     0                     0
# 1473893                        0                     0                     0
# 1387922                        0                     0                     0
# 223191                         0                     0                     0
#
#          Incident_TEST_TYPE_1  Incident_TEST_TYPE_2  Incident_TEST_TYPE_3  \
# 1750087                     0                     0                     0
# 1473893                     0                     0                     0
# 1387922                     0                     0                     0
# 223191                      0                     0                     0
#
#          Incident_TEST_TYPE_4  Incident_TEST_TYPE_5
# 1750087                     0                     0
# 1473893                     0                     0
# 1387922                     0                     0
# 223191                      0                     0
#
# [4 rows x 62 columns]

# %%
# creating features for train test split
X = train_data.drop(['Patient-Uid', 'Date', 'Target','Year','Month'],axis=1)
y = train_data['Target']

# %%
# Splitting the data into training

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
# Balancing minority class using oversampling minority class

from imblearn.over_sampling import SMOTE

smt =SMOTE(random_state = 42)
X_smt, y_smt = smt.fit_resample(X_train, y_train)

# %%
# Build a predictive model using a random forest classifier

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_smt, y_smt)
preds = model.predict(X_test)

# %%
print(preds)
# Out:
# [0 0 0 ... 0 0 0]

# %%
# Evaluate the model

from sklearn.metrics import f1_score

f1=f1_score(y_test, preds)
print("F1-Score on validation set:", f1)
# Out:
# F1-Score on validation set: 1.0

# %%
# prediction for Test dataset

test_df = pd.read_parquet("test.parquet")
test_df.head(1)
# Out:
#                             Patient-Uid       Date        Incident
# 0  a0f9e8a9-1c7c-11ec-8d25-16262ee38c7f 2016-12-08  SYMPTOM_TYPE_0

# %%
# Encoding Incident feature

test_df = pd.get_dummies(test_df, columns=['Incident'])

# %%
test_df.head(2)
# Out:
#                             Patient-Uid       Date  Incident_DRUG_TYPE_0  \
# 0  a0f9e8a9-1c7c-11ec-8d25-16262ee38c7f 2016-12-08                     0
# 1  a0f9e8a9-1c7c-11ec-8d25-16262ee38c7f 2018-10-17                     1
#
#    Incident_DRUG_TYPE_1  Incident_DRUG_TYPE_10  Incident_DRUG_TYPE_11  \
# 0                     0                      0                      0
# 1                     0                      0                      0
#
#    Incident_DRUG_TYPE_12  Incident_DRUG_TYPE_13  Incident_DRUG_TYPE_14  \
# 0                      0                      0                      0
# 1                      0                      0                      0
#
#    Incident_DRUG_TYPE_15  ...  Incident_SYMPTOM_TYPE_6  \
# 0                      0  ...                        0
# 1                      0  ...                        0
#
#    Incident_SYMPTOM_TYPE_7  Incident_SYMPTOM_TYPE_8  Incident_SYMPTOM_TYPE_9  \
# 0                        0                        0                        0
# 1                        0                        0                        0
#
#    Incident_TEST_TYPE_0  Incident_TEST_TYPE_1  Incident_TEST_TYPE_2  \
# 0                     0                     0                     0
# 1                     0                     0                     0
#
#    Incident_TEST_TYPE_3  Incident_TEST_TYPE_4  Incident_TEST_TYPE_5
# 0                     0                     0                     0
# 1                     0                     0                     0
#
# [2 rows x 57 columns]

# %%
# Adding column features to same column as Train dataset

test_df["Incident_DRUG_TYPE_18"]= 0

# %%
test_df["Incident_TARGET DRUG"]= 0

# %%
Test_data=test_df.drop(["Patient-Uid","Date"],axis=1)
Test_data.head(2)
# Out:
#    Incident_DRUG_TYPE_0  Incident_DRUG_TYPE_1  Incident_DRUG_TYPE_10  \
# 0                     0                     0                      0
# 1                     1                     0                      0
#
#    Incident_DRUG_TYPE_11  Incident_DRUG_TYPE_12  Incident_DRUG_TYPE_13  \
# 0                      0                      0                      0
# 1                      0                      0                      0
#
#    Incident_DRUG_TYPE_14  Incident_DRUG_TYPE_15  Incident_DRUG_TYPE_16  \
# 0                      0                      0                      0
# 1                      0                      0                      0
#
#    Incident_DRUG_TYPE_17  ...  Incident_SYMPTOM_TYPE_8  \
# 0                      0  ...                        0
# 1                      0  ...                        0
#
#    Incident_SYMPTOM_TYPE_9  Incident_TEST_TYPE_0  Incident_TEST_TYPE_1  \
# 0                        0                     0                     0
# 1                        0                     0                     0
#
#    Incident_TEST_TYPE_2  Incident_TEST_TYPE_3  Incident_TEST_TYPE_4  \
# 0                     0                     0                     0
# 1                     0                     0                     0
#
#    Incident_TEST_TYPE_5  Incident_TARGET DRUG  Incident_DRUG_TYPE_18
# 0                     0                     0                      0
# 1                     0                     0                      0
#
# [2 rows x 57 columns]

# %%
# test data model building & prediction

preds = model.predict(Test_data)
# Out:
# C:\Users\aravi\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)

# %%
# prediction values

pred = pd.DataFrame(preds)
pred
# Out:
#          0
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...     ..
# 1065519  0
# 1065520  0
# 1065521  0
# 1065522  0
# 1065523  0
#
# [1065524 rows x 1 columns]
